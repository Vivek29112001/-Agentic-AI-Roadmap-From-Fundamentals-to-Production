# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\aiml\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\aiml\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\aiml\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\aiml\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\aiml\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\aiml\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\AIML\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
corpus = """Hello welcome, to VYTEQ NLP program.
Please try this exammple in ur nlp journey! let's become experted in NLP.
"""

# %%
print(corpus)
# Out:
# Hello welcome, to VYTEQ NLP program.
# Please try this exammple in ur nlp journey! let's become experted in NLP.

# %%
## tokenization
### sentence _> paragraphs

from nltk.tokenize import sent_tokenize

# %%
sent_tokenize(corpus)
# Out:
# ['Hello welcome, to VYTEQ NLP program.',
#  'Please try this exammple in ur nlp journey!',
#  "let's become experted in NLP."]

# %%
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello welcome, to VYTEQ NLP program.
# Please try this exammple in ur nlp journey!
# let's become experted in NLP.

# %% [markdown]
# ## Tokenization
# ### ParagrapH into words
# ### sentence into words

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'VYTEQ',
#  'NLP',
#  'program',
#  '.',
#  'Please',
#  'try',
#  'this',
#  'exammple',
#  'in',
#  'ur',
#  'nlp',
#  'journey',
#  '!',
#  'let',
#  "'s",
#  'become',
#  'experted',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'welcome', ',', 'to', 'VYTEQ', 'NLP', 'program', '.']
# ['Please', 'try', 'this', 'exammple', 'in', 'ur', 'nlp', 'journey', '!']
# ['let', "'s", 'become', 'experted', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'VYTEQ',
#  'NLP',
#  'program',
#  '.',
#  'Please',
#  'try',
#  'this',
#  'exammple',
#  'in',
#  'ur',
#  'nlp',
#  'journey',
#  '!',
#  'let',
#  "'",
#  's',
#  'become',
#  'experted',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'VYTEQ',
#  'NLP',
#  'program.',
#  'Please',
#  'try',
#  'this',
#  'exammple',
#  'in',
#  'ur',
#  'nlp',
#  'journey',
#  '!',
#  'let',
#  "'s",
#  'become',
#  'experted',
#  'in',
#  'NLP',
#  '.']
